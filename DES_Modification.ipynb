# %% [markdown]
# <a href="https://colab.research.google.com/github/isnanramalia/DES-modification/blob/main/DES_Modification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Encryption Standard (DES) - Rounds 20

# %%
# DES Enkripsi

# Function teks ke binary
def text_to_binary(text):
    binary_result = ' '.join(format(ord(char), '08b') for char in text)
    return binary_result.replace(' ', '')

# Function teks ke hexa
def text_to_hex(text):
    hex_result = ''.join(hex(ord(char))[2:] for char in text)
    return hex_result.upper()

#function hexa ke teks
def hex_to_text(hex_string):
    text_result = ''.join(chr(int(hex_string[i:i+2], 16)) for i in range(0, len(hex_string), 2))
    return text_result

# fungsi untuk mengubah binary ke hexa
def bin_to_hex(binary, length):
    bin_to_hex = {"0000" : '0',"0001" : '1',"0010" : '2',"0011" : '3',"0100" : '4',"0101" : '5',"0110" : '6',"0111" : '7',
                  "1000" : '8',"1001" : '9',"1010" : 'A',"1011" : 'B',"1100" : 'C',"1101" : 'D',"1110" : 'E',"1111" : 'F'}
    store = ''
    for i in range(0,length,4):
        store += bin_to_hex[str(binary[i:(i+4)])]
    return store

# fungsi untuk mengubah hexa ke binary
def hex_to_binary(binary, length):
    hex_to_bin = {'0' : "0000", '1' : "0001",'2' : "0010",'3' : "0011",'4' : "0100",'5' : "0101",'6' : "0110",'7' : "0111",
                '8' : "1000",'9' : "1001",'A' : "1010",'B' : "1011",'C' : "1100",'D' : "1101",'E' : "1110",'F' : "1111" }
    store = ''
    for i in range(0,length):
        store += hex_to_bin[str(binary[i])]
    return store

# function xor
def xor(a,b):
    store = ''
    for i in range(len(a)):
        store += str((int(a[i]) + int(b[i])) % 2)
    return store

# mengubah binary yang tipe datanya string ke int agar bisa diolah nilainya
def bin_to_int(binary_string):
    length = len(binary_string) - 1
    number = 0
    for bin in range(length + 1):
        number += int(binary_string[bin]) * (2 ** (length - bin))
    return number

# mengubah integer ke binary
def int_to_bin(integer):
    return bin(integer)[2:]

# digunakan untuk melakukan shifting sesuai banyaknya iterasi
def shifted(bits, shift):
    return bits[shift:] + bits[:shift]

# 00010001
# contoh shift = 2
#  bits[shift:] = bits[2:]
# mengambil nilai bits selain 2 didepan, 00
# bits[:shift] = bits[:2]
# mengambil nilai bits hanya nilai 2 dari depan, 000100
# return  00 + 000100


#   Defines A Function For Permuting Lists of Binary Using Permutation Lookup Tables
def permute(data, permutation_table, length_of_output):
    permutation = ''
    for i in range(length_of_output):
        permutation += data[permutation_table[i] - 1]
    return permutation

# The Inital and Final Permuttions For The DES Algorithm
def IP(data):
    initial_perm = [58, 50, 42, 34, 26, 18, 10, 2, 60, 52, 44, 36, 28, 20, 12, 4,62, 54, 46, 38, 30, 22, 14, 6, 64, 56, 48, 40, 32, 24, 16, 8,
                    57, 49, 41, 33, 25, 17, 9, 1, 59, 51, 43, 35, 27, 19, 11, 3, 61, 53, 45, 37, 29, 21, 13, 5, 63, 55, 47, 39, 31, 23, 15, 7]
    return permute(data, initial_perm, 64)
def IP_Inverse(data):
    inverse_perm = [40, 8, 48, 16, 56, 24, 64, 32, 39, 7, 47, 15, 55, 23, 63, 31, 38, 6, 46, 14, 54, 22, 62, 30, 37, 5, 45, 13, 53, 21, 61, 29,
                    36, 4, 44, 12, 52, 20, 60, 28, 35, 3, 43, 11, 51, 19, 59, 27, 34, 2, 42, 10, 50, 18, 58, 26, 33, 1, 41, 9, 49, 17, 57, 25 ]
    return permute(data, inverse_perm, 64)


#  Inner functions for bit manipulations in the Feistel Function Stages
def f_expansion(bits):
    # This permutation expands the input to 48 bits and provides a layer of 'confusion'
    expansion_perm = [32, 1 , 2 , 3 , 4 , 5 , 4 , 5, 6 , 7 , 8 , 9 , 8 , 9 , 10, 11, 12, 13, 12, 13, 14, 15, 16, 17,
                      16, 17, 18, 19, 20, 21, 20, 21, 22, 23, 24, 25, 24, 25, 26, 27, 28, 29, 28, 29, 30, 31, 32, 1 ]
    return permute(bits, expansion_perm, 48)

def f_key_mixing(bits, key):
    # This function just xor's the key into the message
    return xor(bits, key)

def s_boxes(bits):
    # These substitution boxes are really the core of the DES algorithm, they take six input bits and maps it to 4 output bits
    #       this provides the diffusion necessary to make a secure block cipher (not that DES is secure, because it is not)
    sboxes =   [[[14, 4, 13, 1, 2, 15, 11, 8, 3, 10, 6, 12, 5, 9, 0, 7], [0, 15, 7, 4, 14, 2, 13, 1, 10, 6, 12, 11, 9, 5, 3, 8], [4, 1, 14, 8, 13, 6, 2, 11, 15, 12, 9, 7, 3, 10, 5, 0], [15, 12, 8, 2, 4, 9, 1, 7, 5, 11, 3, 14, 10, 0, 6, 13 ]],
                [[15, 1, 8, 14, 6, 11, 3, 4, 9, 7, 2, 13, 12, 0, 5, 10], [3, 13, 4, 7, 15, 2, 8, 14, 12, 0, 1, 10, 6, 9, 11, 5], [0, 14, 7, 11, 10, 4, 13, 1, 5, 8, 12, 6, 9, 3, 2, 15], [13, 8, 10, 1, 3, 15, 4, 2, 11, 6, 7, 12, 0, 5, 14, 9 ]],
                [[10, 0, 9, 14, 6, 3, 15, 5, 1, 13, 12, 7, 11, 4, 2, 8], [13, 7, 0, 9, 3, 4, 6, 10, 2, 8, 5, 14, 12, 11, 15, 1], [13, 6, 4, 9, 8, 15, 3, 0, 11, 1, 2, 12, 5, 10, 14, 7], [1, 10, 13, 0, 6, 9, 8, 7, 4, 15, 14, 3, 11, 5, 2, 12 ]],
                [[7, 13, 14, 3, 0, 6, 9, 10, 1, 2, 8, 5, 11, 12, 4, 15], [13, 8, 11, 5, 6, 15, 0, 3, 4, 7, 2, 12, 1, 10, 14, 9], [10, 6, 9, 0, 12, 11, 7, 13, 15, 1, 3, 14, 5, 2, 8, 4], [3, 15, 0, 6, 10, 1, 13, 8, 9, 4, 5, 11, 12, 7, 2, 14 ]],
                [[2, 12, 4, 1, 7, 10, 11, 6, 8, 5, 3, 15, 13, 0, 14, 9], [14, 11, 2, 12, 4, 7, 13, 1, 5, 0, 15, 10, 3, 9, 8, 6], [4, 2, 1, 11, 10, 13, 7, 8, 15, 9, 12, 5, 6, 3, 0, 14], [11, 8, 12, 7, 1, 14, 2, 13, 6, 15, 0, 9, 10, 4, 5, 3 ]],
                [[12, 1, 10, 15, 9, 2, 6, 8, 0, 13, 3, 4, 14, 7, 5, 11], [10, 15, 4, 2, 7, 12, 9, 5, 6, 1, 13, 14, 0, 11, 3, 8], [9, 14, 15, 5, 2, 8, 12, 3, 7, 0, 4, 10, 1, 13, 11, 6], [4, 3, 2, 12, 9, 5, 15, 10, 11, 14, 1, 7, 6, 0, 8, 13 ]],
                [[4, 11, 2, 14, 15, 0, 8, 13, 3, 12, 9, 7, 5, 10, 6, 1], [13, 0, 11, 7, 4, 9, 1, 10, 14, 3, 5, 12, 2, 15, 8, 6], [1, 4, 11, 13, 12, 3, 7, 14, 10, 15, 6, 8, 0, 5, 9, 2], [6, 11, 13, 8, 1, 4, 10, 7, 9, 5, 0, 15, 14, 2, 3, 12 ]],
                [[13, 2, 8, 4, 6, 15, 11, 1, 10, 9, 3, 14, 5, 0, 12, 7], [1, 15, 13, 8, 10, 3, 7, 4, 12, 5, 6, 11, 0, 14, 9, 2], [7, 11, 4, 1, 9, 12, 14, 2, 0, 6, 10, 13, 15, 3, 5, 8], [2, 1, 14, 7, 4, 10, 8, 13, 15, 12, 9, 0, 3, 5, 6, 11 ]]]
    # Split the bytes into 8 substrings, split those substrings into the outer and inner bits,
    #       and use them as indexes for the lookup in the sboxes, convert to binary and pad zeros if necessary
    substituted_string = ''
    for i in range(0,48,6):
        substring = (bits[0:48][i:i+6])
        row = bin_to_int(substring[0] + substring[5])
        column = bin_to_int(substring[1] + substring[2] + substring[3] + substring[4])
        lookup = int_to_bin(sboxes[int(i/6)][row][column])
        if len(lookup) < 4:
            lookup = ((4 - len(lookup)) * '0') + lookup
        substituted_string += lookup

    return substituted_string

# The Feistel function includes a final permutation, for added 'confusion' in each round.
def f_permute(bits):
    p_box = [16, 7, 20, 21, 29, 12, 28, 17, 1, 15, 23, 26, 5, 18, 31, 10, 2, 8, 24, 14, 32, 27, 3, 9, 19, 13, 30, 6, 22, 11, 4, 25]
    return permute(bits, p_box, 32)


# The Feistel Function Called During Encryption and Decryption
def f(bytes, key): # bytes = right_half , 32 bit
    expanded = f_expansion(bytes)
    mixed = f_key_mixing(expanded, key)
    substituted = s_boxes(mixed)
    permutation = f_permute(substituted)
    return permutation


##############################################################################################
# The Round Function: This is a very important function, it is the core of the Feistel Network
#     that makes up DES. It is called 16 times with different keys from the keyschedule and
#     each time the inputs are mapped to the outputs (after the Feistel Function is called)
###############################################################################################
def round(left_half, right_half, key):
    new_right_half = xor(left_half, f(right_half, key))
    return right_half, new_right_half


#############################################################
# The Key Schedule Generator
#   This function generates the sixteen subkeys for DES
#############################################################
def generate_keys(initial_state):
    if len(initial_state) != 64:
        if len(initial_state) == 16:
            initial_state = hex_to_binary(initial_state, 16)
        else:
            return 'ERROR MESSAGE NOT PROPER SIZE'

    pc_1 = [57, 49, 41, 33, 25, 17, 9, 1, 58, 50, 42, 34, 26, 18, 10, 2, 59, 51, 43, 35, 27, 19, 11, 3, 60, 52, 44, 36,
            63, 55, 47, 39, 31, 23, 15, 7, 62, 54, 46, 38, 30, 22, 14, 6, 61, 53, 45, 37, 29, 21, 13, 5, 28, 20, 12, 4]
    pc_2 = [14, 17, 11, 24, 1, 5, 3, 28, 15, 6, 21, 10, 23, 19, 12, 4, 26, 8, 16, 7, 27, 20, 13, 2, 41,
            52, 31, 37, 47, 55, 30, 40, 51, 45, 33, 48, 44, 49, 39, 56, 34, 53, 46, 42, 50, 36, 29, 32 ]

    permuted = permute(initial_state, pc_1, 56)
    key_schedule = []
    left_half, right_half = permuted[0:28], permuted[28:56]

    for loop in range(20):
        if loop in {0, 1, 8, 9, 10, 11, 12, 13, 16, 17, 18, 19}:
            left_half, right_half = shifted(left_half, 1), shifted(right_half, 1)
        else:
            left_half, right_half = shifted(left_half, 2), shifted(right_half, 2)

        key_schedule.append(permute((left_half + right_half), pc_2, 48))

    return key_schedule


####################################################################
#   THE MAIN ENCRYPTION FUNCTION FOR DES
#       This function encrypts a block of 64 bits using
#       a 64 bit key (this is supposed to include parity bits)
####################################################################
def encrypt(message, key):
    if len(message) != 64:
        if len(message) == 16:
            message = hex_to_binary(message, 16)
        else:
            return 'ERROR MESSAGE NOT PROPER SIZE'

    key_schedule = generate_keys(key)

    print('Data Being Encrypted: ', bin_to_hex(message, 64))
    perm = IP(message)
    print('After Initial Permutation: ', bin_to_hex(perm, 64))

    left_half, right_half = perm[0:32], perm[32:64]

    print(' ' * 20, 'Left Half  ', 'Right Half ', 'Sub Key  ')
    for loop in range(20):  # Mengubah jumlah putaran menjadi 20
        left_half, right_half = round(left_half, right_half, key_schedule[loop])

        print('Round: ', loop + 1, ' ', left_half, ' ', right_half, ' ', key_schedule[loop])

    cyphertext = IP_Inverse(right_half + left_half)
    return cyphertext

####################################################################
#   THE MAIN DECRYPTION FUNCTION FOR DES
#       This function decrypts a block of 64 bits using
#       a 64 bit key (this is supposed to include parity bits)
#       It is the same as encrypton algorithm but  with an upside
#       down key schedule.
####################################################################
def decrypt(message, key):
    if len(message) != 64:
        if len(message) == 16:
            message = hex_to_binary(message, 16)
        else:
            return 'ERROR MESSAGE NOT PROPER SIZE'
    key_schedule = generate_keys(key)

    print('Data Being Encrypted:      ', bin_to_hex(message, 64))
    perm = IP(message)
    print('After Initial Permutation: ', bin_to_hex(perm, 64))
    left_half, right_half = perm[0:32], perm[32:64]
    print(' ' * 20, 'Left Half  ',' ' * 20, 'Right Half ',' ' * 20, 'Sub Key  ')
    for loop in range(20):  # Mengubah jumlah putaran menjadi 20
        left_half, right_half = round(left_half, right_half, key_schedule[19 - loop])  # Melakukan reverse key schedule

        print('Round: ', loop + 1, ' ', left_half, ' ', right_half, ' ', key_schedule[loop])

    cyphertext = IP_Inverse(right_half + left_half)

    return cyphertext

# Membuat teks menjadi 8 huruf dan dimasukan kedalam array
def modif_plain(par):
    while len(par) % 8 != 0:
        par += "-"
    par_arr = [par[i:i+8] for i in range(0, len(par), 8)]
    return par_arr

def modif_cipher(par):
    while len(par) % 64 != 0:
        par += "-"
    par_arr = [par[i:i+64] for i in range(0, len(par), 64)]
    return par_arr



def encrypt_print(plain , key):
  hasil_encrypt = []
  hasil_encrypt_hexa= []

  hex_key = text_to_hex(key)

  for i in plain:
    e = encrypt(text_to_binary(i), hex_key)
    encrypt_hexa =  bin_to_hex(''.join(e) , 64)
    encrypt_text =  hex_to_text(bin_to_hex(''.join(e) , 64))
    hasil_encrypt.append(e)
    hasil_encrypt_hexa.append(encrypt_hexa)


  print("Hasil enkrip dalam bentuk biner = " ,  ''.join(hasil_encrypt))
  print("Hasil enkrip dalam bentuk hexa =  " , ''.join(hasil_encrypt_hexa) )

  return hasil_encrypt

def decrypt_print(chiper , key):
  hex_key = text_to_hex(key)
  # print(cipher_modif)
  hasil_decrpyt = []
  for x in chiper:
    hasil_decrpyt.append(hex_to_text( bin_to_hex(decrypt(x, hex_key), 64)))

  print("Plain Text =" ,''.join(hasil_decrpyt).rstrip('-'))
  return hasil_decrpyt

def main():
  while True:
        print("\nPilihlah salah satu dari pilihan berikut:")
        print("1. Encrypt")
        print("2. Decrypt")
        print("3. Keluar dari program")
        choice = input("Masukkan pilihan Anda: ")

        if choice == '1':
            plain_text = input("Masukkan plain text untuk dienkripsi :  ")
            plain_modif = modif_plain(plain_text)
            key = input("Masukan key text ( 64 bit / 8 huruf ) : ")
            hasil = encrypt_print(plain_modif , key)

        elif choice == '2':
            cipher_text = input("Masukkan cipher text (dalam binary): ")
            key = input("Masukkan kunci: ")
            cipher_modif = modif_cipher(cipher_text)
            hasil = decrypt_print(cipher_modif , key)

        elif choice == '3':
            print("Terima kasih, program selesai.")
            break
        else:
            print("Pilihan tidak valid. Silakan pilih 1, 2, atau 3.")



main()
# Out:
# Pilihlah salah satu dari pilihan berikut:
# 1. Encrypt
# 2. Decrypt
# 3. Keluar dari program
# Masukkan pilihan Anda: 1
# Masukkan plain text untuk dienkripsi :  tugumuda
# Masukan key text ( 64 bit / 8 huruf ) : dinusian
# Data Being Encrypted:  747567756D756461
# After Initial Permutation:  FF2B7FBE00FF1004
#                      Left Half   Right Half  Sub Key
# Round:  1   00000000111111110001000000000100   00111011001100110011100010011100   111000001011111001101110111000010010110100101100
# Round:  2   00111011001100110011100010011100   11100011010101111001000010111011   111000001011011011110110000001111101011000010001
# Round:  3   11100011010101111001000010111011   11010101001100000001010100011001   111101001101011001110110100110110010010101100000
# Round:  4   11010101001100000001010100011001   10100110100101110111011100100000   111001101101001101110010101010001100101100000100
# Round:  5   10100110100101110111011100100000   01111001100100101001100110011011   101011101101001101110111010100000110011010010110
# Round:  6   01111001100100101001100110011011   11001100001110001100111010110011   101011110101001101011011111111010000000010001001
# Round:  7   11001100001110001100111010110011   01100000000000010011110100100111   001011110101001111111001100000100111001001001011
# Round:  8   01100000000000010011110100100111   10100101010011001000110011001010   100111110101100111011001001101101011001100100100
# Round:  9   10100101010011001000110011001010   10011100000011101110001101010111   000111110100100111011011000011100100000000011111
# Round:  10   10011100000011101110001101010111   10010100101010101011010000110001   000111110110101111011001101100000000110111100010
# Round:  11   10010100101010101011010000110001   10001011000110010010100001100010   001111110110100110011101010001110111000111000100
# Round:  12   10001011000110010010100001100010   10111010010001010100000001001000   000111110111110110001101010011001010101000010011
# Round:  13   10111010010001010100000001001000   01010101000000100001001011010101   000111110010110110001101101000001000000111101001
# Round:  14   01010101000000100001001011010101   10111000000010101111000111111111   010110110010110111001101011101110110010001011000
# Round:  15   10111000000010101111000111111111   11101011100100111110100101011011   010110011110110010101101001010011001000101001010
# Round:  16   11101011100100111110100101011011   10110101111001100100011001011111   110100011010110110101110100001001111010000100110
# Round:  17   10110101111001100100011001011111   10100011110001100011010011111110   110100101010111010101110000110010101100101001001
# Round:  18   10100011110001100011010011111110   00100110011011101110001001011100   111100001010111010100111011011000000111011100100
# Round:  19   00100110011011101110001001011100   01000000000001010100011101000011   111110001011111000100110010000101111000000110000
# Round:  20   01000000000001010100011101000011   10101000001000110001100011011101   111100011011111000100110100110001100100011011011
# Hasil enkrip dalam bentuk biner =  0011101100011010001010010100010100000101010100001000101101000001
# Hasil enkrip dalam bentuk hexa =   3B1A294505508B41
#
# Pilihlah salah satu dari pilihan berikut:
# 1. Encrypt
# 2. Decrypt
# 3. Keluar dari program
# Masukkan pilihan Anda: 2
# Masukkan cipher text (dalam binary): 0011101100011010001010010100010100000101010100001000101101000001
# Masukkan kunci: dinusian
# Data Being Encrypted:       3B1A294505508B41
# After Initial Permutation:  A82318DD40054743
#                      Left Half                        Right Half                       Sub Key
# Round:  1   01000000000001010100011101000011   00100110011011101110001001011100   111000001011111001101110111000010010110100101100
# Round:  2   00100110011011101110001001011100   10100011110001100011010011111110   111000001011011011110110000001111101011000010001
# Round:  3   10100011110001100011010011111110   10110101111001100100011001011111   111101001101011001110110100110110010010101100000
# Round:  4   10110101111001100100011001011111   11101011100100111110100101011011   111001101101001101110010101010001100101100000100
# Round:  5   11101011100100111110100101011011   10111000000010101111000111111111   101011101101001101110111010100000110011010010110
# Round:  6   10111000000010101111000111111111   01010101000000100001001011010101   101011110101001101011011111111010000000010001001
# Round:  7   01010101000000100001001011010101   10111010010001010100000001001000   001011110101001111111001100000100111001001001011
# Round:  8   10111010010001010100000001001000   10001011000110010010100001100010   100111110101100111011001001101101011001100100100
# Round:  9   10001011000110010010100001100010   10010100101010101011010000110001   000111110100100111011011000011100100000000011111
# Round:  10   10010100101010101011010000110001   10011100000011101110001101010111   000111110110101111011001101100000000110111100010
# Round:  11   10011100000011101110001101010111   10100101010011001000110011001010   001111110110100110011101010001110111000111000100
# Round:  12   10100101010011001000110011001010   01100000000000010011110100100111   000111110111110110001101010011001010101000010011
# Round:  13   01100000000000010011110100100111   11001100001110001100111010110011   000111110010110110001101101000001000000111101001
# Round:  14   11001100001110001100111010110011   01111001100100101001100110011011   010110110010110111001101011101110110010001011000
# Round:  15   01111001100100101001100110011011   10100110100101110111011100100000   010110011110110010101101001010011001000101001010
# Round:  16   10100110100101110111011100100000   11010101001100000001010100011001   110100011010110110101110100001001111010000100110
# Round:  17   11010101001100000001010100011001   11100011010101111001000010111011   110100101010111010101110000110010101100101001001
# Round:  18   11100011010101111001000010111011   00111011001100110011100010011100   111100001010111010100111011011000000111011100100
# Round:  19   00111011001100110011100010011100   00000000111111110001000000000100   111110001011111000100110010000101111000000110000
# Round:  20   00000000111111110001000000000100   11111111001010110111111110111110   111100011011111000100110100110001100100011011011
# Plain Text = tugumuda
#
# Pilihlah salah satu dari pilihan berikut:
# 1. Encrypt
# 2. Decrypt
# 3. Keluar dari program
